# %% [markdown]
# <a href="https://colab.research.google.com/github/LucjanSakowicz/data-science-bootcamp/blob/main/09_exercises/151_160_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas
#
# ### Spis treści:
# * [Import biblioteki](#0)
# * [Ćwiczenie 151](#1)
# * [Ćwiczenie 152](#2)
# * [Ćwiczenie 153](#3)
# * [Ćwiczenie 154](#4)
# * [Ćwiczenie 155](#5)
# * [Ćwiczenie 156](#6)
# * [Ćwiczenie 157](#7)
# * [Ćwiczenie 158](#8)
# * [Ćwiczenie 159](#9)
# * [Ćwiczenie 160](#10)

# %% [markdown]
# ### <a name='0'></a>Import biblioteki

# %%
import numpy as np
import pandas as pd

np.random.seed(42)
np.__version__
# Out:
# '1.22.4'

# %% [markdown]
# ### <a name='1'></a> Ćwiczenie 151
# Podany jest poniższy obiekt _DataFrame:_
#
# ```
# df = pd.DataFrame(np.random.rand(10, 4), columns=list('ABCD'))
# ```

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=list('ABCD'))

# %% [markdown]
# Wytnij wiersze obiektu _df_ dla których kolumna _C_ jest większa niż 0.8.
# Pomocniczo: Analogicznie jak w jezyku SQL poniższe zapytanie:
#
#
# ```
# SELECT * FROM df WHERE C > 0.8
# ```

# %%
df.query('C > 0.8')
# Out:
#           A         B         C         D
# 4  0.690938  0.386735  0.936730  0.137521
# 5  0.341066  0.113474  0.924694  0.877339
# 6  0.257942  0.659984  0.817222  0.555201
# 9  0.725956  0.897110  0.887086  0.779876

# %% [markdown]
# ### <a name='2'></a> Ćwiczenie 152
#
# Wytnij wiersze obiektu _df_ dla których kolumna _C_ jest większa niż 0.3 oraz kolumna _D_ jest mniejsza niż 0.7.

# %%
df.query('C > 0.3 & D < 0.7')
# Out:
#           A         B         C         D
# 0  0.367783  0.632306  0.633530  0.535775
# 1  0.090290  0.835302  0.320780  0.186519
# 2  0.040775  0.590893  0.677564  0.016588
# 3  0.512093  0.226496  0.645173  0.174366
# 4  0.690938  0.386735  0.936730  0.137521
# 6  0.257942  0.659984  0.817222  0.555201
# 8  0.900418  0.633101  0.339030  0.349210

# %% [markdown]
# ### <a name='3'></a> Ćwiczenie 153
# Dokonaj iteracji po pierwszych pięciu wierszach obiektu _df_. Każdy wiersz wydrukuj do konsoli.
#
# __Wskazówka:__ Wykorzystaj funkcję _pd.DataFrame.iterrows()_.

# %%
for index, row in df.head(5).iterrows():
  print(row)
# Out:
# A    0.367783
# B    0.632306
# C    0.633530
# Name: 0, dtype: float64
# A    0.090290
# B    0.835302
# C    0.320780
# Name: 1, dtype: float64
# A    0.040775
# B    0.590893
# C    0.677564
# Name: 2, dtype: float64
# A    0.512093
# B    0.000000
# C    0.645173
# Name: 3, dtype: float64
# A    0.690938
# B    0.386735
# C    0.936730
# Name: 4, dtype: float64

# %% [markdown]
# ### <a name='4'></a> Ćwiczenie 154
# Ustaw wartość w wierszu o indeksie 3 dla kolumny B jako _np.nan_.
# Wykorzystaj _df.iloc_.

# %%
df.iloc[3, 1] = np.nan
df
# Out:
# <ipython-input-57-aa2fa2a112c6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[3, 1] = np.nan
#           A         B         C
# 0  0.367783  0.632306  0.633530
# 1  0.090290  0.835302  0.320780
# 2  0.040775  0.590893  0.677564
# 3  0.512093       NaN  0.645173
# 4  0.690938  0.386735  0.936730
# 5  0.341066  0.113474  0.924694
# 6  0.257942  0.659984  0.817222
# 7  0.529651  0.241852  0.093103
# 8  0.900418  0.633101  0.339030
# 9  0.725956  0.897110  0.887086

# %% [markdown]
# Ustaw wartość w wierszu o indeksie 8 dla kolumny D jako _np.nan_. Wykorzystaj _df.loc_.

# %%
df.loc[7, 'D'] = np.nan
df
# Out:
#           A         B         C         D
# 0  0.367783  0.632306  0.633530  0.535775
# 1  0.090290  0.835302  0.320780  0.186519
# 2  0.040775  0.590893  0.677564  0.016588
# 3  0.512093       NaN  0.645173  0.174366
# 4  0.690938  0.386735  0.936730  0.137521
# 5  0.341066  0.113474  0.924694  0.877339
# 6  0.257942  0.659984  0.817222  0.555201
# 7  0.529651  0.241852  0.093103       NaN
# 8  0.900418  0.633101  0.339030  0.349210
# 9  0.725956  0.897110  0.887086  0.779876

# %% [markdown]
# Wyświetl obiekt _df_.

# %%
df
# Out:
#           A         B         C         D
# 0  0.367783  0.632306  0.633530  0.535775
# 1  0.090290  0.835302  0.320780  0.186519
# 2  0.040775  0.590893  0.677564  0.016588
# 3  0.512093       NaN  0.645173  0.174366
# 4  0.690938  0.386735  0.936730  0.137521
# 5  0.341066  0.113474  0.924694  0.877339
# 6  0.257942  0.659984  0.817222  0.555201
# 7  0.529651  0.241852  0.093103       NaN
# 8  0.900418  0.633101  0.339030  0.349210
# 9  0.725956  0.897110  0.887086  0.779876

# %% [markdown]
# ### <a name='5'></a> Ćwiczenie 155
# Usuń wszystkie wiersze z obiektu _df_ zawierające braki danych i przypisz do zmiennej _df1_. Wyświetl zmienną _df1_.

# %%
print()
df1 = df[df.isnull().any(axis=1)]
df.dropna(how='all').dropna(how='all', axis=1, inplace=True)
df1
# Out:
#           A         B         C         D
# 3  0.512093       NaN  0.645173  0.174366
# 7  0.529651  0.241852  0.093103       NaN

# %% [markdown]
# ### <a name='6'></a> Ćwiczenie 156
# Zauważ, że indeks po usunięciu dwóch wieszy w obiekcie _df1_ nie jest po kolei. Zresetuj indeks, aby wprowadzić kolejność (nie dodawaj nowej kolumny, tylko zreseuj indeks). Wyświetl zmienną _df1_.

# %%
df1.reset_index(inplace=True)
df1
# Out:
#    index         A         B         C         D
# 0      3  0.512093       NaN  0.645173  0.174366
# 1      7  0.529651  0.241852  0.093103       NaN

# %% [markdown]
# ### <a name='7'></a> Ćwiczenie 157
# Wracamy do obiektu _df_. Wyznacz liczbę brakujących elementów w obiekcie _df_ dla każdej kolumny.

# %%
df.isna().sum()
# Out:
# A    0
# B    1
# C    0
# D    1
# dtype: int64

# %% [markdown]
# ### <a name='8'></a> Ćwiczenie 158
# Uzupełnij brakujące wartości wartością 0 i przypisz do zmiennej _df_.

# %%
df = df.fillna(0)
df
# Out:
#           A         B         C         D
# 0  0.367783  0.632306  0.633530  0.535775
# 1  0.090290  0.835302  0.320780  0.186519
# 2  0.040775  0.590893  0.677564  0.016588
# 3  0.512093  0.000000  0.645173  0.174366
# 4  0.690938  0.386735  0.936730  0.137521
# 5  0.341066  0.113474  0.924694  0.877339
# 6  0.257942  0.659984  0.817222  0.555201
# 7  0.529651  0.241852  0.093103  0.000000
# 8  0.900418  0.633101  0.339030  0.349210
# 9  0.725956  0.897110  0.887086  0.779876

# %% [markdown]
# ### <a name='9'></a> Ćwiczenie 159
# Zamień kolejność kolumn w obiekcie _df_ na podaną poniżej:
# * D, A, B, C
#
# i przypisz do zmiennej _df_.

# %%
df = df.iloc[:, [3,0,1,2]]

#lub

df = df[['D', 'A', 'B', 'C']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-ad2eea553b0d> in <cell line: 1>()
# ----> 1 df = df.iloc[:, [3,0,1,2]]
#       2
#       3 #lub
#       4
#       5 df = df[['D', 'A', 'B', 'C']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1561     def _getitem_tuple(self, tup: tuple):
#    1562
# -> 1563         tup = self._validate_tuple_indexer(tup)
#    1564         with suppress(IndexingError):
#    1565             return self._getitem_lowerdim(tup)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _validate_tuple_indexer(self, key)
#     871         for i, k in enumerate(key):
#     872             try:
# --> 873                 self._validate_key(k, i)
#     874             except ValueError as err:
#     875                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1479             # check that the key does not exceed the maximum size of the index
#    1480             if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
# -> 1481                 raise IndexError("positional indexers are out-of-bounds")
#    1482         else:
#    1483             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# IndexError: positional indexers are out-of-bounds

# %% [markdown]
# ### <a name='10'></a> Ćwiczenie 160
# Usuń kolumnę $D$ z obiektu _df_.

# %%
df.drop(['D'], axis=1, inplace=True)

#lub
def df['D']
df
# Out:
# <ipython-input-55-108a2718662b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['D'], axis=1, inplace=True)
#           A         B         C
# 0  0.367783  0.632306  0.633530
# 1  0.090290  0.835302  0.320780
# 2  0.040775  0.590893  0.677564
# 3  0.512093  0.000000  0.645173
# 4  0.690938  0.386735  0.936730
# 5  0.341066  0.113474  0.924694
# 6  0.257942  0.659984  0.817222
# 7  0.529651  0.241852  0.093103
# 8  0.900418  0.633101  0.339030
# 9  0.725956  0.897110  0.887086
